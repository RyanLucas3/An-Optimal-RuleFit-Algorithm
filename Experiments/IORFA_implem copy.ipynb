# %%
import gurobipy
import pandas as pd
from IORFA import *
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from pauls_functions_advanced import *
# Out:
# WARNING:root:There is a more recent IAI release (v3.1.1) available.
# WARNING:root:This copy of Interpretable AI software is for academic purposes only and not for commercial use.
# WARNING:root:Interpretable AI license expires soon: 2022-12-31T00:00:00. If you need to renew, please send us the following machine ID:
# 18d872627be647b0178f56f4ee2d1bfee29192a168717377dc73402f8855d847

# %%
depth = 2

# %%
def find_rules_from_node_x(x, odt):

    # Find the active splits (those that are actually used) at the first node
    active_splits_at_node_x =  {i: odt.a[i] for i in list(odt.a.keys()) if (i[1] == x and odt.a[i].X == 1)}

    # Store the splitting variable and the threshold together
    for key in list(active_splits_at_node_x.keys()):
        active_splits_at_node_x[(key[0], odt.b[x].X)] = active_splits_at_node_x[key]
        del active_splits_at_node_x[key]

    # Make rules out of them
    rules_from_node_x = {(f"X[:, {key[0]}] <= " + str(key[1]), 
                        f"X[:, {key[0]}] > " + str(key[1]) )           
                        for key in active_splits_at_node_x.keys()}
    
    return rules_from_node_x

def chain_rules(odt):
    
    rules_N1 = list(find_rules_from_node_x(1, odt))[0]
    rules_N2 = list(find_rules_from_node_x(2, odt))[0]
    rules_N3 = list(find_rules_from_node_x(3, odt))[0]

    path1 = "(" + rules_N1[0] + ")" + " * " + "(" + (rules_N2[0]) + ")"
    path2 = "(" +(rules_N1[0])+ ")" + " * " + "(" + (rules_N2[1]) + ")"
    path3 = "(" +(rules_N1[1]) + ")" + " * " +  "(" +(rules_N3[0]) + ")"
    path4 = "(" +(rules_N1[1]) + ")" + " * " + "(" +(rules_N3[1]) + ")"


    return [path1, path2, path3, path4]


def add_rules_to_df(rules, X):

    X = np.matrix(X)

    for rule in rules:
        rule_ind = [1 if i in np.where(eval(rule))[0] else 0 for i in range(X.shape[0]) ]
        X = pd.DataFrame(X)
        X[rule] = rule_ind
    
    return X

def IORFA(X, odt):
    rules = chain_rules(odt)
    betas = [odt.beta[i].X for i in list(odt.beta.keys())]
    gammas = [odt.gamma[i].X for i in list(odt.gamma.keys())]
    coefficients = betas + gammas
    rule_df = np.matrix(add_rules_to_df(rules, X))
    preds = []
    for i in range(X.shape[0]):
        y_i = sum(rule_df[i, j]*coefficients[j] for j in range(len(coefficients)))
        preds.append(y_i)
    
    return preds

# %%
X = np.random.normal(size = (200, 10))

X = (X - np.min(X)) / (np.max(X) - np.min(X))

x1 = X[:, 0]
x2 = X[:, 1]

y = 0 + 1.0*x1 + 2*x2 + 1*(x1 < 0.3)*(x2 >-0.3)

odt = optimalDecisionTreeClassifier(max_depth=depth,warmstart=True,output=False)
odt.fit(X, y)

preds = IORFA(X, odt)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-11-30

# %%
r2_score(preds, y)
# Out:
# 1.0

# %%
iters = 10
names = ['Reg-CART','CART','ORT','OCT','ORT-H','OCT-H']

r2s = {i: {} for i in range(iters)}

np.random.seed(22)

for iter in range(iters):


        X = np.random.normal(size = (200, 10))

        X = (X - np.min(X)) / (np.max(X) - np.min(X))

        x1 = X[:, 0]
        x2 = X[:, 1]

        y = 0 + 0.6*x1 + 0.5*x2 + 1*(x1 < 0.3)*(x2 >-0.3)

        odt = optimalDecisionTreeClassifier(max_depth=depth,warmstart=True,output=True)
        odt.fit(X, y)

        preds = IORFA(X, odt)

        r2s[iter]['IORFA'] = r2_score(preds, y)

        X = pd.DataFrame(X)

        models, performance = generate_tree(X, y, X, y, 
                                            n_num=2, feat_size=2,  max_iter_hy=2, 
                                            depth_bi=2, depth_hy=2, complexity_bi=0.001, 
                                        complexity_hy=0.001, depth_grid_bi=False, depth_grid_hy=False, 
                                        Reg_CART=True, ORT=True, ORT_H=False, 
                                        Clas_CART=False, OCT=False, OCT_H=False)

        act_name = []
        act_rules = []
        for model,name in zip(models,names):
            if not not model:
                act_name += [name]
                act_rules += [model]

        for column in X.columns:
            X.rename(columns = {column: str(column)},  inplace = True)


        datasets = gen_train_and_test_features(act_rules, act_name, X, X)

        log_reg_acc = linear_regression_pipeline(X, X, y, y)

        r2s[iter]["Linear Regression"] = log_reg_acc
        r2s[iter]["Reg CART"] = performance['Reg CART'].iloc[0]
        r2s[iter]["ORT"] = performance['ORT'].iloc[0]

        for model in datasets.keys():

            X_train_rules_and_features, X_test_rules_and_features = datasets[model][0]
            X_train_only_rules, X_test_only_rules = datasets[model][1]

            only_rules_acc = linear_regression_pipeline(X_train_only_rules, X_test_only_rules, y, y)

            rules_and_features_acc = linear_regression_pipeline(X_train_rules_and_features, X_test_rules_and_features, y, y)

            r2s[iter][model + "_rules_and_features"] = rules_and_features_acc
# Out:
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0x20c13a0f
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [2e-05, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [7e-01, 1e+02]
#   QObjective range [4e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 8.26994 (0.35s)
# User MIP start produced solution with objective 8.26969 (0.41s)
# User MIP start produced solution with objective 8.26963 (0.70s)
# User MIP start produced solution with objective 8.25606 (1.71s)
# User MIP start produced solution with objective -1.13687e-13 (1.72s)
# Loaded user MIP start with objective -1.13687e-13
# Processed MIP start in 1.71 seconds (1.07 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.07s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 148 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        -0.00000   -0.00000  0.00%     -    1s
#
# Explored 1 nodes (148 simplex iterations) in 1.90 seconds (1.15 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: -1.13687e-13 8.25606 8.26963 8.26994
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.136868377216e-13, best bound -1.136868377216e-13, gap 0.0000%
# [ Warning: This copy of Interpretable AI software is for academic purposes only and not for commercial use.
# ┌ Warning: Interpretable AI license expires soon: 2022-12-31T00:00:00. If you need to renew, please send us the following machine ID:
# └ 18d872627be647b0178f56f4ee2d1bfee29192a168717377dc73402f8855d847
# Regression CART mean performance:  0.07276689455328367
#
#
# Regression ORT performance:  0.1504961283828904
#
#
# Regression CART mean performance:  0.8620783793778308
#
#
# Regression ORT performance:  0.8841206576141009
#
#
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0xf8a977ea
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [2e-05, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [6e-01, 1e+02]
#   QObjective range [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 8.24886 (0.28s)
# User MIP start produced solution with objective 7.80354 (0.36s)
# User MIP start produced solution with objective 7.68679 (0.59s)
# User MIP start produced solution with objective 7.64799 (1.06s)
# User MIP start produced solution with objective 6.66888 (1.12s)
# User MIP start produced solution with objective 5.91523 (1.20s)
# User MIP start produced solution with objective 4.26326e-14 (1.22s)
# Loaded user MIP start with objective 4.26326e-14
# Processed MIP start in 1.23 seconds (1.45 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.04s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 209 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.00000    0.00000  0.00%     -    1s
#
# Explored 1 nodes (209 simplex iterations) in 1.37 seconds (1.55 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 4.26326e-14 5.91523 6.66888 ... 8.24886
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.263256414561e-14, best bound 4.263256414561e-14, gap 0.0000%
# Regression CART mean performance:  0.18315810952047573
#
#
# Regression ORT performance:  0.20326347239046816
#
#
# Regression CART mean performance:  0.07607505883305143
#
#
# Regression ORT performance:  0.13829898910486393
#
#
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0x339b6029
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [8e-06, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [6e-01, 1e+02]
#   QObjective range [7e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 15.0199 (0.39s)
# User MIP start produced solution with objective 14.498 (0.45s)
# User MIP start produced solution with objective 14.461 (0.73s)
# User MIP start produced solution with objective -5.68434e-14 (1.50s)
# Loaded user MIP start with objective -5.68434e-14
# Processed MIP start in 1.49 seconds (1.14 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.05s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 375 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        -0.00000   -0.00000  0.00%     -    1s
#
# Explored 1 nodes (375 simplex iterations) in 1.66 seconds (1.22 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: -5.68434e-14 14.461 15.0199
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.684341886081e-14, best bound -5.684341886081e-14, gap 0.0000%
# Regression CART mean performance:  0.10117038285724911
#
#
# Regression ORT performance:  0.1362691874473032
#
#
# Regression CART mean performance:  0.06855534652933737
#
#
# Regression ORT performance:  0.10685390565512587
#
#
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0x57a0ec9e
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [2e-06, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [4e-01, 1e+02]
#   QObjective range [1e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 16.729 (0.32s)
# User MIP start produced solution with objective 10.5333 (0.41s)
# User MIP start produced solution with objective 9.98598 (0.42s)
# User MIP start produced solution with objective 9.98128 (0.57s)
# User MIP start produced solution with objective 9.69542 (0.73s)
# User MIP start produced solution with objective 1.27898e-13 (1.39s)
# Loaded user MIP start with objective 1.27898e-13
# Processed MIP start in 1.39 seconds (1.30 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.04s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 329 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.00000    0.00000  0.00%     -    1s
#
# Explored 1 nodes (329 simplex iterations) in 1.52 seconds (1.39 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1.27898e-13 9.69542 9.98128 ... 16.729
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.278976924368e-13, best bound 1.278976924368e-13, gap 0.0000%
# Regression CART mean performance:  0.9220627117133714
#
#
# Regression ORT performance:  0.9220627117133714
#
#
# Regression CART mean performance:  0.1340709628760619
#
#
# Regression ORT performance:  0.15384337845266183
#
#
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0xec55ca7c
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [2e-05, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [6e-01, 1e+02]
#   QObjective range [1e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 14.8151 (0.24s)
# User MIP start produced solution with objective 11.4809 (0.29s)
# User MIP start produced solution with objective 11.4325 (0.52s)
# User MIP start produced solution with objective 8.3955 (1.62s)
# User MIP start produced solution with objective 8.38178 (1.64s)
# User MIP start produced solution with objective 7.74774 (1.78s)
# User MIP start produced solution with objective 0.670548 (1.79s)
# User MIP start produced solution with objective 0.248859 (2.26s)
# User MIP start produced solution with objective 0.163696 (2.67s)
# User MIP start produced solution with objective 2.55795e-13 (2.91s)
# Loaded user MIP start with objective 2.55795e-13
# Processed MIP start in 2.91 seconds (2.48 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.04s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 388 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.00000    0.00000  0.00%     -    3s
#
# Explored 1 nodes (388 simplex iterations) in 3.06 seconds (2.59 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 2.55795e-13 0.163696 0.248859 ... 14.8151
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.557953848736e-13, best bound 2.557953848736e-13, gap 0.0000%
# Regression CART mean performance:  0.061385359152222096
#
#
# Regression ORT performance:  0.11309702921232334
#
#
# Regression CART mean performance:  0.07225514141995382
#
#
# Regression ORT performance:  0.12710046448704182
#
#
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0x8f7bdf3a
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [4e-05, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [5e-01, 1e+02]
#   QObjective range [1e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 8.87512 (0.22s)
# User MIP start produced solution with objective 8.82914 (0.27s)
# User MIP start produced solution with objective 8.72218 (0.29s)
# User MIP start produced solution with objective 8.71116 (1.36s)
# User MIP start produced solution with objective 8.66223 (2.10s)
# User MIP start produced solution with objective 8.65988 (2.31s)
# User MIP start produced solution with objective -2.55795e-13 (2.60s)
# Loaded user MIP start with objective -2.55795e-13
# Processed MIP start in 2.60 seconds (2.52 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.04s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 197 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        -0.00000   -0.00000  0.00%     -    2s
#
# Explored 1 nodes (197 simplex iterations) in 2.74 seconds (2.62 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: -2.55795e-13 8.65988 8.71116 ... 8.87512
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.557953848736e-13, best bound -2.557953848736e-13, gap 0.0000%
# Regression CART mean performance:  0.11942670392602972
#
#
# Regression ORT performance:  0.16614496022184622
#
#
# Regression CART mean performance:  0.19892360033700307
#
#
# Regression ORT performance:  0.23600541178487855
#
#
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0x28645cf3
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [3e-06, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [6e-01, 1e+02]
#   QObjective range [4e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 19.7863 (0.25s)
# User MIP start produced solution with objective 19.7199 (0.31s)
# User MIP start produced solution with objective 19.5311 (0.38s)
# User MIP start produced solution with objective 19.1956 (0.39s)
# User MIP start produced solution with objective 18.6764 (0.61s)
# User MIP start produced solution with objective 5.03042 (1.36s)
# User MIP start produced solution with objective 9.9476e-14 (1.37s)
# Loaded user MIP start with objective 9.9476e-14
# Processed MIP start in 1.36 seconds (1.25 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.04s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 434 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.00000    0.00000  0.00%     -    1s
#
# Explored 1 nodes (434 simplex iterations) in 1.51 seconds (1.35 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 9.9476e-14 5.03042 18.6764 ... 19.7863
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.947598300641e-14, best bound 9.947598300641e-14, gap 0.0000%
# Regression CART mean performance:  0.945706600300459
#
#
# Regression ORT performance:  0.945706600300459
#
#
# Regression CART mean performance:  0.06517183481824151
#
#
# Regression ORT performance:  0.12333347746175638
#
#
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0x3ff6fb0b
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [2e-05, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [6e-01, 1e+02]
#   QObjective range [6e-02, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 13.2865 (0.31s)
# User MIP start produced solution with objective 12.9196 (0.40s)
# User MIP start produced solution with objective 12.8805 (0.58s)
# User MIP start produced solution with objective 12.7898 (1.69s)
# User MIP start produced solution with objective 12.7816 (1.92s)
# User MIP start produced solution with objective 7.10543e-14 (1.97s)
# Loaded user MIP start with objective 7.10543e-14
# Processed MIP start in 1.97 seconds (1.98 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.06s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 271 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.00000    0.00000  0.00%     -    2s
#
# Explored 1 nodes (271 simplex iterations) in 2.18 seconds (2.08 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 7.10543e-14 12.7816 12.8805 13.2865
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.105427357601e-14, best bound 7.105427357601e-14, gap 0.0000%
# Regression CART mean performance:  0.11701203011890704
#
#
# Regression ORT performance:  0.11701203011890704
#
#
# Regression CART mean performance:  0.09969733634478539
#
#
# Regression ORT performance:  0.10049130211110868
#
#
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0xc2cf947f
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [4e-05, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [7e-01, 1e+02]
#   QObjective range [4e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 6.8231 (0.30s)
# User MIP start produced solution with objective 6.64769 (0.38s)
# User MIP start produced solution with objective 6.63865 (0.48s)
# User MIP start produced solution with objective 6.6376 (0.65s)
# User MIP start produced solution with objective 6.62146 (2.31s)
# User MIP start produced solution with objective 6.30783 (2.45s)
# User MIP start produced solution with objective 6.30776 (2.46s)
# User MIP start produced solution with objective 6.30724 (2.50s)
# User MIP start produced solution with objective 6.30633 (2.51s)
# User MIP start produced solution with objective 6.28362 (3.54s)
# User MIP start produced solution with objective 6.27555 (3.72s)
# User MIP start produced solution with objective 6.27207 (3.86s)
# User MIP start produced solution with objective 5.42946 (3.94s)
# User MIP start produced solution with objective 1.42109e-14 (4.01s)
# Loaded user MIP start with objective 1.42109e-14
# Processed MIP start in 4.01 seconds (3.91 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.06s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 125 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.00000    0.00000  0.00%     -    4s
#
# Explored 1 nodes (125 simplex iterations) in 4.20 seconds (4.02 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 1.42109e-14 5.42946 6.27207 ... 6.62146
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.421085471520e-14, best bound 1.421085471520e-14, gap 0.0000%
# Regression CART mean performance:  0.2390188892272872
#
#
# Regression ORT performance:  0.2822685387711018
#
#
# Regression CART mean performance:  0.22949640329663712
#
#
# Regression ORT performance:  0.2822685387711018
#
#
# Training data include 200 instances, 10 features.
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2616 rows, 2058 columns and 24047 nonzeros
# Model fingerprint: 0x250b60b0
# Model has 2254 quadratic objective terms
# Model has 200 quadratic constraints
# Variable types: 1221 continuous, 837 integer (837 binary)
# Coefficient statistics:
#   Matrix range     [2e-05, 2e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [6e-01, 1e+02]
#   QObjective range [1e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 800 unfixed non-continuous variables out of 837
# User MIP start produced solution with objective 7.70241 (0.41s)
# User MIP start produced solution with objective 5.99726 (0.54s)
# User MIP start produced solution with objective 5.78049 (2.16s)
# User MIP start produced solution with objective 8.52651e-14 (2.18s)
# Loaded user MIP start with objective 8.52651e-14
# Processed MIP start in 2.17 seconds (1.63 work units)
#
# Presolve removed 9 rows and 1007 columns
# Presolve time: 0.04s
# Presolved: 4407 rows, 3451 columns, 27430 nonzeros
# Presolved model has 1600 SOS constraint(s)
# Presolved model has 2254 quadratic objective terms
# Variable types: 1817 continuous, 1634 integer (1634 binary)
#
# Root relaxation: cutoff, 136 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.00000    0.00000  0.00%     -    2s
#
# Explored 1 nodes (136 simplex iterations) in 2.30 seconds (1.72 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 8.52651e-14 5.78049 5.99726 7.70241
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.526512829121e-14, best bound 8.526512829121e-14, gap 0.0000%
# Regression CART mean performance:  0.07750290941340032
#
#
# Regression ORT performance:  0.15776415251370046
#
#
# Regression CART mean performance:  0.16965380436824828
#
#
# Regression ORT performance:  0.17324631241819577

# %%
r2s
# Out:
# {0: {'IORFA': 0.8991702174820012,
#   'Linear Regression': 0.1166788327052668,
#   'Reg CART': 0.07276689455328367,
#   'ORT': 0.1504961283828904,
#   'Reg-CART_rules_and_features': 1.0,
#   'ORT_rules_and_features': 1.0},
#  1: {'IORFA': 1.0,
#   'Linear Regression': 0.24798167498923096,
#   'Reg CART': 0.18315810952047573,
#   'ORT': 0.20326347239046816,
#   'Reg-CART_rules_and_features': 0.39884299922816757,
#   'ORT_rules_and_features': 0.5181101140386519},
#  2: {'IORFA': 0.9468265436074466,
#   'Linear Regression': 0.2329596336413472,
#   'Reg CART': 0.10117038285724911,
#   'ORT': 0.1362691874473032,
#   'Reg-CART_rules_and_features': 0.34508633640622155,
#   'ORT_rules_and_features': 0.36168198057644096},
#  3: {'IORFA': 0.9478263293322673,
#   'Linear Regression': 0.2303979736475863,
#   'Reg CART': 0.9220627117133714,
#   'ORT': 0.9220627117133714,
#   'Reg-CART_rules_and_features': 1.0,
#   'ORT_rules_and_features': 1.0},
#  4: {'IORFA': 1.0,
#   'Linear Regression': 0.302937531403058,
#   'Reg CART': 0.061385359152222096,
#   'ORT': 0.11309702921232334,
#   'Reg-CART_rules_and_features': 0.4034267260540385,
#   'ORT_rules_and_features': 0.40244312411204586},
#  5: {'IORFA': 1.0,
#   'Linear Regression': 0.12462838288847133,
#   'Reg CART': 0.11942670392602972,
#   'ORT': 0.16614496022184622,
#   'Reg-CART_rules_and_features': 0.2881703382129086,
#   'ORT_rules_and_features': 0.30926842333246973},
#  6: {'IORFA': 0.9548042499481761,
#   'Linear Regression': 0.2958134974983937,
#   'Reg CART': 0.945706600300459,
#   'ORT': 0.945706600300459,
#   'Reg-CART_rules_and_features': 1.0,
#   'ORT_rules_and_features': 1.0},
#  7: {'IORFA': 1.0,
#   'Linear Regression': 0.28318392619906385,
#   'Reg CART': 0.11701203011890704,
#   'ORT': 0.11701203011890704,
#   'Reg-CART_rules_and_features': 0.3965071027938373,
#   'ORT_rules_and_features': 0.40426127978878346},
#  8: {'IORFA': 1.0,
#   'Linear Regression': 0.24951269404610077,
#   'Reg CART': 0.2390188892272872,
#   'ORT': 0.2822685387711018,
#   'Reg-CART_rules_and_features': 0.29327668402742024,
#   'ORT_rules_and_features': 0.32157349890502585},
#  9: {'IORFA': 1.0,
#   'Linear Regression': 0.22701555657690298,
#   'Reg CART': 0.07750290941340032,
#   'ORT': 0.15776415251370046,
#   'Reg-CART_rules_and_features': 0.38442773702896804,
#   'ORT_rules_and_features': 0.48188561099664873}}

# %%
results = pd.DataFrame(r2s)

# %%
results
# Out:
#                                     0         1         2         3         4  \
# IORFA                        0.899170  1.000000  0.946827  0.947826  1.000000
# Linear Regression            0.116679  0.247982  0.232960  0.230398  0.302938
# Reg CART                     0.072767  0.183158  0.101170  0.922063  0.061385
# ORT                          0.150496  0.203263  0.136269  0.922063  0.113097
# Reg-CART_rules_and_features  1.000000  0.398843  0.345086  1.000000  0.403427
# ORT_rules_and_features       1.000000  0.518110  0.361682  1.000000  0.402443
#
#                                     5         6         7         8         9
# IORFA                        1.000000  0.954804  1.000000  1.000000  1.000000
# Linear Regression            0.124628  0.295813  0.283184  0.249513  0.227016
# Reg CART                     0.119427  0.945707  0.117012  0.239019  0.077503
# ORT                          0.166145  0.945707  0.117012  0.282269  0.157764
# Reg-CART_rules_and_features  0.288170  1.000000  0.396507  0.293277  0.384428
# ORT_rules_and_features       0.309268  1.000000  0.404261  0.321573  0.481886

# %%
results = results.T

# %%
benchmark_cols = list(results.columns[1:])

benchmark_cols.append("IORFA")

results = results[benchmark_cols]

# %%
results.rename(columns = {"Reg-CART_rules_and_features": "RuleFit", "ORT_rules_and_features": "ORFA", "Linear Regression": "Lin. Regression"}, inplace = True)

# %%
results.iloc[:25]
# Out:
#    Lin. Regression  Reg CART       ORT   RuleFit      ORFA     IORFA
# 0         0.116679  0.072767  0.150496  1.000000  1.000000  0.899170
# 1         0.247982  0.183158  0.203263  0.398843  0.518110  1.000000
# 2         0.232960  0.101170  0.136269  0.345086  0.361682  0.946827
# 3         0.230398  0.922063  0.922063  1.000000  1.000000  0.947826
# 4         0.302938  0.061385  0.113097  0.403427  0.402443  1.000000
# 5         0.124628  0.119427  0.166145  0.288170  0.309268  1.000000
# 6         0.295813  0.945707  0.945707  1.000000  1.000000  0.954804
# 7         0.283184  0.117012  0.117012  0.396507  0.404261  1.000000
# 8         0.249513  0.239019  0.282269  0.293277  0.321573  1.000000
# 9         0.227016  0.077503  0.157764  0.384428  0.481886  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax= plt.subplots()


fig.set_size_inches(17, 10)
sns.boxplot(data = results.iloc[:25], ax= ax)
ax.set_ylim(0, 1.1)


sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'white'})
sns.set_style("whitegrid")
ax.yaxis.grid(False) # Hide the horizontal gridlines
ax.xaxis.grid(True) # Show the vertical gridlines

ax.set_title("IORFA versus various benchmarks on simulated data", fontsize = 22)
ax.set_ylabel(r"$R^2$", rotation = 0, fontsize = 21, labelpad = 20)
# ax.set_ylim(0.3, 1.05)


ax.tick_params(rotation =0, labelsize = 17)

# %%
results.mean()
