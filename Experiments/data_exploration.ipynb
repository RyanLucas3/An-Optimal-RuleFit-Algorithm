# %%
from ex_func import *
from experiment_functions import *
import pandas as pd
from pmlb import fetch_data, classification_dataset_names
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, f_classif
import pickle
# Out:
# WARNING:root:This copy of Interpretable AI software is for academic purposes only and not for commercial use.

# %%
path = "/Users/paulchristophroeseler/Dropbox (MIT)/PycharmProjects/pythonProject/ORRFA-2/results/"

# %%
depth_3_results = pd.read_csv(path + "results_level3.csv")
depth_4_results = pd.read_csv(path + "results_level4.csv")

# %%
grid_search_results = pd.read_csv(path + "result_girdsearch.csv")

# %%
# k = depth_4_results
# k = k.stack(level=2).sort_index()
# k = k.stack(level=2).sort_index()
# k = k.swaplevel(axis=1)
# k = k.droplevel(0)

# %%
multi_idx = pd.MultiIndex.from_tuples((grid_search_results.columns[i], grid_search_results.iloc[0].values[i]) for i in range(len(grid_search_results.columns)))

# %%
grid_search_results.columns = multi_idx

# %%
grid_search_results = grid_search_results.iloc[1: , :]

# %%
grid_search_results
# Out:
#    Unnamed: 0 Unnamed: 1                                        CART  \
#           NaN        NaN GAMETES_Epistasis_2_Way_20atts_0.1H_EDM_1_1
# 1         0.0        0.5                                         NaN
# 2         0.0          1                                    0.521875
# 3         0.0        1.2                                         NaN
# 4         0.0        1.4                                         NaN
# 5         0.0        1.6                                         NaN
# 6         0.0        1.8                                         NaN
# 7         0.0          2                                         NaN
# 8         0.0        2.5                                         NaN
# 9         0.0          3                                         NaN
# 10        0.0        all                                         NaN
# 11        1.0        0.5                                         NaN
# 12        1.0          1                                         0.5
# ...

# %%
cart_oct = grid_search_results[grid_search_results[grid_search_results.columns[1]]== '1']

# %%
cart_oct = cart_oct.astype(float)

# %%
cart_oct.mean(axis=0)
# Out:
# Unnamed: 0                      NaN                                            2.000000
# Unnamed: 1                      NaN                                            1.000000
# CART                            GAMETES_Epistasis_2_Way_20atts_0.1H_EDM_1_1    0.513125
# CART_KNN_rules                  GAMETES_Epistasis_2_Way_20atts_0.1H_EDM_1_1    0.525000
# CART_KNN_rules_and_features     GAMETES_Epistasis_2_Way_20atts_0.1H_EDM_1_1    0.558333
#                                                                                  ...
# OCT_SVM_rules_and_features.129  yeast                                          0.470270
# ORT.130                         yeast                                               NaN
# ORT-H.130                       yeast                                               NaN
# Reg-CART.130                    yeast                                               NaN
# Support Vector Machine.130      yeast                                          0.597973
# ...

# %%
cart_oct[cart_oct.index.isin(['Log',''])]

# %%
mean_df = pd.DataFrame(cart_oct.mean(axis=0))

# %%
mean_df.reset_index(inplace=True)

# %%
mean_df['level_0']
# Out:
# 0                           Unnamed: 0
# 1                           Unnamed: 1
# 2                                 CART
# 3                       CART_KNN_rules
# 4          CART_KNN_rules_and_features
#                      ...
# 4427    OCT_SVM_rules_and_features.129
# 4428                           ORT.130
# 4429                         ORT-H.130
# 4430                      Reg-CART.130
# 4431        Support Vector Machine.130
# Name: level_0, Length: 4432, dtype: object

# %%
df[df.index.get_level_values('PBL_AWI').isin(['Lake', 'River', 'Upland'])]

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")
